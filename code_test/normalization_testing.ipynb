# %% [markdown]
# # testing normalization
#
# trained several models with and without joint training encoder as well as normalziation

# %%
import sys
from evals.evals_utils_joint import Evals
ckpt_path = '/data1/lesliec/sarthak/caduceus/outputs/2026-01-09/13-40-19-009544/checkpoints/last.ckpt'
base = Evals(ckpt_path, load_data=False)

ckpt_path = '/data1/lesliec/sarthak/caduceus/outputs/2026-01-09/13-41-12-595393/checkpoints/last.ckpt'
batchnorm = Evals(ckpt_path, load_data=False)

ckpt_path = '/data1/lesliec/sarthak/caduceus/outputs/2026-01-09/13-43-51-477571/checkpoints/last.ckpt'
instancenorm = Evals(ckpt_path, load_data=False)

#these nexxt 2 are not joint training, so separate CNN for each input
ckpt_path = '/data1/lesliec/sarthak/caduceus/outputs/2026-01-09/14-40-05-177299/checkpoints/last.ckpt'
mixednorm = Evals(ckpt_path, load_data=False)

ckpt_path = '/data1/lesliec/sarthak/caduceus/outputs/2026-01-09/14-42-36-020358/checkpoints/last.ckpt'
batchnorm2 = Evals(ckpt_path, load_data=False)

# %%
base.encoder #we see that it doesn't have a normalization layer as expected, is identity
#but we can look at the others to see it does

# %%
batchnorm2.encoder
