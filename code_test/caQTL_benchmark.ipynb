# %% [markdown]
# # now caQTL benchmark

# %%
#this should be similar to dsqtl, first let's see if rsids make sense!

import pandas as pd

bims = {}
for i in range(1,23):
    bim_path = f'/data1/deyk/extras/1000G_BIMS_hg38/1000G.EUR.QC.{i}.bim'
    bim = pd.read_csv(bim_path, sep='\t', header=None)
    bims[i] = bim


bim_pos = {
    chrom: dict(zip(bims[chrom][1].values, bims[chrom][3].index))
    for chrom in bims
}

rsids = ['rs58108140','rs777038595'] #first 2 rsids
chrom = 1
for rsid in rsids:
    bimrow = bim_pos[chrom].get(rsid, None)
    # bimrow = bim_pos[chrom][rsid]
    print(bimrow)
# Out:
# None
# None

# %%
rsids = ['rs58108140','rs777038595','rs879707275'] #first 2 rsids
chrom = 1
for rsid in rsids:
    bimrow = bim_pos[chrom].get(rsid, None)
    # bimrow = bim_pos[chrom][rsid]
    print(bimrow)
# Out:
# None
# None
# None

# %%
bim_pos[chrom]
# Out:
# {'rs575272151': 0,
#  'rs544419019': 1,
#  'rs540538026': 2,
#  'rs62635286': 3,
#  'rs200579949': 4,
#  'rs531730856': 5,
#  'rs554008981': 6,
#  'rs546169444': 7,
#  'rs531646671': 8,
#  'rs541940975': 9,
#  'rs199856693': 10,
#  'rs564003018': 11,
#  'rs374029747': 12,
#  'rs568149713': 13,
#  'rs2691315': 14,
#  'rs199745162': 15,
#  'rs564023708': 16,
#  'rs533090414': 17,
#  'rs806731': 18,
#  'rs542415070': 19,
#  'rs559500163': 20,
#  'rs528344458': 21,
#  'rs551668143': 22,
#  'rs565211799': 23,
#  'rs559190862': 24,
#  'rs575564077': 25,
#  'rs2691277': 26,
#  'rs530867301': 27,
#  'rs141149254': 28,
#  'rs552304420': 29,
#  'rs569799965': 30,
#  'rs3091274': 31,
#  'rs114420996': 32,
#  'rs547227933': 33,
#  'rs62637817': 34,
#  'rs541415601': 35,
#  'rs527362206': 36,
#  'rs184286948': 37,
#  'rs62637820': 38,
#  'rs557590765': 39,
#  'rs62639100': 40,
#  'rs80011619': 41,
#  'rs552815263': 42,
#  'rs181431124': 43,
#  'rs62639104': 44,
#  'rs181028663': 45,
# ...

# %%
#let's get the rows
all_caqtl = pd.read_csv('/data1/lesliec/sarthak/data/joint_playground/caQTL/QTD100018.all.tsv', sep='\t', nrows=10000)
all_caqtl
# Out:
#      molecular_trait_id  chromosome  position ref alt          variant  \
# 0            Interval_1           1     10583   G   A   chr1_10583_G_A
# 1            Interval_2           1     10583   G   A   chr1_10583_G_A
# 2            Interval_3           1     10583   G   A   chr1_10583_G_A
# 3            Interval_4           1     10583   G   A   chr1_10583_G_A
# 4            Interval_5           1     10583   G   A   chr1_10583_G_A
# ...                 ...         ...       ...  ..  ..              ...
# 9995        Interval_16           1    830725   T   A  chr1_830725_T_A
# 9996        Interval_17           1    830725   T   A  chr1_830725_T_A
# 9997        Interval_18           1    830725   T   A  chr1_830725_T_A
# 9998        Interval_19           1    830725   T   A  chr1_830725_T_A
# 9999        Interval_20           1    830725   T   A  chr1_830725_T_A
#
#       ma_samples       maf    pvalue      beta        se type   ac   an  r2  \
# ...

# %%
rsids = all_caqtl['rsid'].values
rsids[0]
# Out:
# 'rs58108140'

# %%
missing = 0
for rsid in rsids:
    bimrow = bim_pos[chrom].get(rsid, None)
    # bimrow = bim_pos[chrom][rsid]
    if bimrow is not None:
        print(bimrow)
    else:
        # print(f"Missing rsid: {rsid}")
        missing += 1
print(f"Missing rsids: {missing}") #most are missing, but let's take a look at the ones that are there!
# Out:
# 7
# 7
# 7
# 7
# 7
# 7
# 10
# 10
# 10
# 10
# 10
# 10
# 15
# 15
# 15
# 15
# 15
# 15
# 28
# 28
# 28
# 28
# 28
# 28
# 32
# 32
# 32
# 32
# 32
# 32
# 34
# 34
# 34
# 34
# 34
# 34
# 41
# 41
# 41
# 41
# 41
# 41
# 44
# 44
# 44
# 44
# 44
# 44
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 68
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 72
# 76
# 76
# 76
# 76
# 76
# 76
# 76
# 76
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 80
# 86
# 86
# 86
# 86
# 86
# 86
# 86
# 86
# 94
# 94
# 94
# 94
# 94
# 94
# 95
# 95
# 95
# 95
# 95
# 95
# 101
# 101
# 101
# 101
# 101
# 101
# 110
# 110
# 110
# 112
# 112
# 112
# 114
# 114
# 114
# 120
# 120
# 120
# 161
# 161
# 161
# 161
# 161
# 161
# 161
# 161
# 194
# 194
# 194
# 194
# 194
# 194
# 194
# 194
# 194
# 194
# 194
# 194
# 196
# 196
# 196
# 196
# 196
# 196
# 196
# 196
# 196
# 196
# 196
# 196
# 196
# 196
# 197
# 197
# 197
# 197
# 197
# 197
# 197
# 197
# 197
# 197
# 197
# 197
# 197
# 197
# 197
# 198
# 198
# 198
# 198
# 198
# 198
# 198
# 198
# 198
# 198
# 198
# 198
# 198
# 198
# 198
# 198
# 201
# ...

# %%
missing = 0
for rsid in rsids:
    bimrow = bim_pos[chrom].get(rsid, None)
    # bimrow = bim_pos[chrom][rsid]
    if bimrow is not None:
        print(bimrow)
        print(rsid)
        bimval = bims[chrom].iloc[bimrow]
        print(bimval)
        break
# Out:
# 7
# rs546169444
# 0              1
# 1    rs546169444
# 2            0.0
# 3          14464
# 4              T
# 5              A
# Name: 7, dtype: object

# %%
#now subset allcaqtl to this rsid
tempqtl = all_caqtl[all_caqtl['rsid'] == rsid]
tempqtl
#so this is interesting because it clearly has repeats, just these beta and se values differ, i have no clue why!
# Out:
#    molecular_trait_id  chromosome  position ref alt         variant  \
# 36         Interval_1           1     14464   A   T  chr1_14464_A_T
# 37         Interval_2           1     14464   A   T  chr1_14464_A_T
# 38         Interval_3           1     14464   A   T  chr1_14464_A_T
# 39         Interval_4           1     14464   A   T  chr1_14464_A_T
# 40         Interval_5           1     14464   A   T  chr1_14464_A_T
# 41         Interval_6           1     14464   A   T  chr1_14464_A_T
#
#     ma_samples       maf    pvalue      beta        se type  ac   an  r2  \
# 36          48  0.263736  0.071285 -0.328458  0.179592  SNP  48  182 NaN
# 37          48  0.263736  0.167217  0.287697  0.206328  SNP  48  182 NaN
# 38          48  0.263736  0.480256  0.108094  0.152387  SNP  48  182 NaN
# 39          48  0.263736  0.805997 -0.042729  0.173386  SNP  48  182 NaN
# 40          48  0.263736  0.206241  0.222002  0.174157  SNP  48  182 NaN
# ...

# %%
for rsid in rsids:
    bimrow = bim_pos[chrom].get(rsid, None)
    # bimrow = bim_pos[chrom][rsid]
    if bimrow == 10:
        print(bimrow)
        print(rsid)
        bimval = bims[chrom].iloc[bimrow]
        print(bimval)
        break
tempqtl = all_caqtl[all_caqtl['rsid'] == rsid]
tempqtl
#so where the rsids match, it's definitely identical, let's verify
# Out:
# 10
# rs199856693
# 0              1
# 1    rs199856693
# 2            0.0
# 3          14933
# 4              A
# 5              G
# Name: 10, dtype: object
#    molecular_trait_id  chromosome  position ref alt         variant  \
# 48         Interval_1           1     14933   G   A  chr1_14933_G_A
# 49         Interval_2           1     14933   G   A  chr1_14933_G_A
# 50         Interval_3           1     14933   G   A  chr1_14933_G_A
# 51         Interval_4           1     14933   G   A  chr1_14933_G_A
# 52         Interval_5           1     14933   G   A  chr1_14933_G_A
# 53         Interval_6           1     14933   G   A  chr1_14933_G_A
#
#     ma_samples       maf    pvalue      beta        se type  ac   an  r2  \
# 48          13  0.071429  0.538671  0.163632  0.264955  SNP  13  182 NaN
# 49          13  0.071429  0.251985 -0.346142  0.299896  SNP  13  182 NaN
# 50          13  0.071429  0.074580  0.391881  0.216800  SNP  13  182 NaN
# ...

# %%
for rsid in rsids:
    bimrow = bim_pos[chrom].get(rsid, None)
    # bimrow = bim_pos[chrom][rsid]
    if bimrow is not None:
        bimval = bims[chrom].iloc[bimrow]
        tempqtl = all_caqtl[all_caqtl['rsid'] == rsid]
        assert bimval[3] == tempqtl['position'].values[0], f"Mismatch at rsid {rsid}: {bimval[3]} != {tempqtl['position'].values[0]}"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[18], line 7
#       5 bimval = bims[chrom].iloc[bimrow]
#       6 tempqtl = all_caqtl[all_caqtl['rsid'] == rsid]
# ----> 7 assert bimval[3] == tempqtl['position'].values[0], f"Mismatch at rsid {rsid}: {bimval[3]} != {tempqtl['position'].values[0]}"
#
# AssertionError: Mismatch at rsid rs550285297: 108031 != 108030

# %%
print(bimrow,bimval,sep='\n')
tempqtl
# Out:
# 72
# 0              1
# 1    rs550285297
# 2            0.0
# 3         108031
# 4              T
# 5              G
# Name: 72, dtype: object
#     molecular_trait_id  chromosome  position ref alt          variant  \
# 845         Interval_1           1    108030   G   T  chr1_108030_G_T
# 846         Interval_2           1    108030   G   T  chr1_108030_G_T
# 847         Interval_3           1    108030   G   T  chr1_108030_G_T
# 848         Interval_4           1    108030   G   T  chr1_108030_G_T
# 849         Interval_5           1    108030   G   T  chr1_108030_G_T
# 850         Interval_6           1    108030   G   T  chr1_108030_G_T
# 851         Interval_7           1    108030   G   T  chr1_108030_G_T
# 852         Interval_8           1    108030   G   T  chr1_108030_G_T
#
#      ma_samples       maf    pvalue      beta        se type  ac   an  r2  \
# 845           8  0.043956  0.714561 -0.122386  0.333399  SNP   8  182 NaN
# ...

# %%
#ok so they're very close but why are they different?? let's see the reference value
import numpy as np
genome = np.load('/data1/lesliec/sarthak/data/chrombpnet_test/hg38_tokenized.npz')
pos = bimval[3]-1
print(genome['chr1'][pos:pos+2]) #they're both G which matches the reference, so wtf?
# Out:
# [10 10]

# %%
for rsid in rsids:
    bimrow = bim_pos[chrom].get(rsid, None)
    # bimrow = bim_pos[chrom][rsid]
    if bimrow is not None:
        bimval = bims[chrom].iloc[bimrow]
        tempqtl = all_caqtl[all_caqtl['rsid'] == rsid]
        if bimval[3] != tempqtl['position'].values[0]:
            print(f"Mismatch at rsid {rsid}: {bimval[3]} != {tempqtl['position'].values[0]}")
#ok so it's fine  other than that one example, let's get a larger list
# Out:
# Mismatch at rsid rs550285297: 108031 != 108030
# Mismatch at rsid rs550285297: 108031 != 108030
# Mismatch at rsid rs550285297: 108031 != 108030
# Mismatch at rsid rs550285297: 108031 != 108030
# Mismatch at rsid rs550285297: 108031 != 108030
# Mismatch at rsid rs550285297: 108031 != 108030
# Mismatch at rsid rs550285297: 108031 != 108030
# Mismatch at rsid rs550285297: 108031 != 108030

# %%
all_caqtl = pd.read_csv('/data1/lesliec/sarthak/data/joint_playground/caQTL/QTD100018.all.tsv', sep='\t', nrows=1_000_000) #original has 350m lines, so we are taking 1/350 of it
all_caqtl
# Out:
#        molecular_trait_id  chromosome  position ref alt            variant  \
# 0              Interval_1           1     10583   G   A     chr1_10583_G_A
# 1              Interval_2           1     10583   G   A     chr1_10583_G_A
# 2              Interval_3           1     10583   G   A     chr1_10583_G_A
# 3              Interval_4           1     10583   G   A     chr1_10583_G_A
# 4              Interval_5           1     10583   G   A     chr1_10583_G_A
# ...                   ...         ...       ...  ..  ..                ...
# 999995       Interval_690           1  15810821   T   C  chr1_15810821_T_C
# 999996       Interval_691           1  15810821   T   C  chr1_15810821_T_C
# 999997       Interval_692           1  15810821   T   C  chr1_15810821_T_C
# 999998       Interval_693           1  15810821   T   C  chr1_15810821_T_C
# 999999       Interval_694           1  15810821   T   C  chr1_15810821_T_C
#
# ...

# %%
#still only chromosome 1 lmfao!!!!
all_caqtl.iloc[-20:]
# Out:
#        molecular_trait_id  chromosome  position ref alt             variant  \
# 999980       Interval_708           1  15809679  AT   A  chr1_15809679_AT_A
# 999981       Interval_708           1  15809679  AT   A  chr1_15809679_AT_A
# 999982       Interval_709           1  15809679   A  AT  chr1_15809679_A_AT
# 999983       Interval_709           1  15809679   A  AT  chr1_15809679_A_AT
# 999984       Interval_709           1  15809679  AT   A  chr1_15809679_AT_A
# 999985       Interval_709           1  15809679  AT   A  chr1_15809679_AT_A
# 999986       Interval_681           1  15810821   T   C   chr1_15810821_T_C
# 999987       Interval_682           1  15810821   T   C   chr1_15810821_T_C
# 999988       Interval_683           1  15810821   T   C   chr1_15810821_T_C
# 999989       Interval_684           1  15810821   T   C   chr1_15810821_T_C
# 999990       Interval_685           1  15810821   T   C   chr1_15810821_T_C
# ...

# %%
all_caqtl[all_caqtl['chromosome'] == 1].shape #all are chromosome 1!
# Out:
# (1000000, 19)

# %%
rsids = all_caqtl['rsid'].values

# %%
from tqdm import tqdm

mismatch = 0

for rsid in tqdm(rsids):
    bimrow = bim_pos[chrom].get(rsid, None)
    # bimrow = bim_pos[chrom][rsid]
    if bimrow is not None:
        bimval = bims[chrom].iloc[bimrow]
        tempqtl = all_caqtl[all_caqtl['rsid'] == rsid]
        if bimval[3] != tempqtl['position'].values[0]:
            print(f"Mismatch at rsid {rsid}: {bimval[3]} != {tempqtl['position'].values[0]}")
    else:
        mismatch += 1
print(f"Missing rsids: {mismatch}") #most are missing, but let's take a look at the ones that are there!
# Out:
# ...
#   0%|          | 848/1000000 [00:02<36:13, 459.67it/s]
# Mismatch at rsid rs550285297: 108031 != 108030
# Mismatch at rsid rs550285297: 108031 != 108030
# Mismatch at rsid rs550285297: 108031 != 108030
# Mismatch at rsid rs550285297: 108031 != 108030
# Mismatch at rsid rs550285297: 108031 != 108030
# Mismatch at rsid rs550285297: 108031 != 108030
#   0%|          | 905/1000000 [00:02<42:35, 390.89it/s]
# Mismatch at rsid rs550285297: 108031 != 108030
# Mismatch at rsid rs550285297: 108031 != 108030
#   1%|          | 8543/1000000 [01:33<3:00:30, 91.54it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 10
#       8 if bimrow is not None:
#       9     bimval = bims[chrom].iloc[bimrow]
# ---> 10     tempqtl = all_caqtl[all_caqtl['rsid'] == rsid]
#      11     if bimval[3] != tempqtl['position'].values[0]:
# ...

# %%
#improtve speed significantly, predo the lookup
pos_map = dict(zip(all_caqtl['rsid'], all_caqtl['position'])) #I guess assume rsid only has one position
pos_map
# Out:
# {'rs58108140': 10583,
#  'rs777038595': 13417,
#  'rs879707275': 13649,
#  'rs879805273': 13757,
#  'rs796086906': 13868,
#  'rs756427959': 14397,
#  'rs546169444': 14464,
#  'rs1385614989': 14470,
#  'rs199856693': 14933,
#  'rs1171100045': 15112,
#  'rs201635489': 15447,
#  'rs62636367': 16719,
#  'rs62636368': 16841,
#  'rs3891260': 16856,
#  'rs199745162': 16949,
#  'rs201833382': 17005,
#  'rs199740902': 17020,
#  'rs867691030': 17147,
#  'rs200978805': 17222,
#  'rs369606208': 17365,
#  'rs754322362': 17379,
#  'rs201535981': 17385,
#  'rs372841554': 17407,
#  'rs747093451': 17408,
#  'rs200503540': 17452,
#  'rs374545136': 17556,
#  'rs71260069': 17697,
#  'rs376731495': 17722,
#  'rs1190943651': 17730,
#  'rs867399458': 17928,
#  'rs767055815': 17929,
#  'rs879518682': 19217,
#  'rs1254205006': 19248,
#  'rs1164429545': 20094,
#  'rs1293476743': 20098,
#  'rs796202720': 20184,
#  'rs3950648': 20227,
#  'rs1407743745': 20231,
#  'rs11490226': 20250,
#  'rs796745295': 29368,
# ...

# %%
#ensure the mappings are 1 to 1
for i,rsid in enumerate(rsids):
    pos = pos_map[rsid]
    if pos != all_caqtl['position'].values[i]:
        print(f"Mismatch at rsid {rsid}: {pos} != {all_caqtl['position'].values[i]}")
        break
# Out:
# Mismatch at rsid nan: 15675969 != 99002

# %%
i
# Out:
# 693

# %%
all_caqtl.iloc[i] #ok so there's some rsids that are none, we want to remove those!
# Out:
# molecular_trait_id                Interval_1
# chromosome                                 1
# position                               99002
# ref                                       TA
# alt                                        T
# variant                      chr1_99002_TA_T
# ma_samples                                 6
# maf                                 0.032967
# pvalue                              0.467608
# beta                                -0.28351
# se                                  0.388372
# type                                   INDEL
# ac                                         6
# an                                       182
# r2                                       NaN
# molecular_trait_object_id         Interval_1
# gene_id                           Interval_1
# median_tpm                               NaN
# rsid                                     NaN
# Name: 693, dtype: object

# %%
#and remove nans
subset = all_caqtl[~all_caqtl['rsid'].isna()]
rsids = subset['rsid'].values
len(rsids) #small amount of them, just removed
# Out:
# 997133

# %%
#now do the same thing
pos_map = dict(zip(subset['rsid'], subset['position'])) #I guess assume rsid only has one position
for i,rsid in enumerate(rsids):
    pos = pos_map[rsid]
    if pos != subset['position'].values[i]:
        print(f"Mismatch at rsid {rsid}: {pos} != {subset['position'].values[i]}")
        break

# %%
#so now we know they're identical

# %%
mismatch = 0
last_error=None
for rsid in tqdm(rsids):
    bimrow = bim_pos[chrom].get(rsid)
    if bimrow is None:
        mismatch += 1
        continue

    bimval = bims[chrom].iloc[bimrow, 3]      # shorthand: the position column
    qpos   = pos_map.get(rsid)               # O(1) lookup

    if qpos is None:
        mismatch += 1
    elif bimval != qpos and last_error != rsid: #makes it so you don't print every repeat!
        print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}")
        last_error = rsid

print(f"Missing rsids: {mismatch}")
#35% of the rsids are missing, this is just the first million, but relatively promising that most are there?
# Out:
#   2%|▏         | 17469/997133 [00:00<00:05, 174682.25it/s]
# Mismatch at rsid rs550285297: 108031 != 108030
#  14%|█▎        | 136007/997133 [00:01<00:06, 129405.98it/s]
# Mismatch at rsid rs4648606: 1715983 != 1648826
#  51%|█████     | 506198/997133 [00:04<00:03, 131545.68it/s]
# Mismatch at rsid rs1298192: 8802340 != 8802339
# Mismatch at rsid rs1325920: 8879784 != 8879783
#  84%|████████▍ | 838544/997133 [00:07<00:01, 119938.39it/s]
# Mismatch at rsid rs367644024: 13376388 != 13376386
# Mismatch at rsid rs2359299: 13802 != 13377099
# Mismatch at rsid rs535777764: 180745 != 13381678
# Mismatch at rsid rs555599845: 180772 != 13381705
# Mismatch at rsid rs201387011: 13391968 != 13391965
# Mismatch at rsid rs200149212: 13391970 != 13391966
# 100%|██████████| 997133/997133 [00:08<00:00, 117738.12it/s]
# Missing rsids: 342224

# %%
#now let's check the other weird examples
mismatch = 0
last_error=None
all_mismatch = []
matched = 0
for rsid in tqdm(rsids):
    bimrow = bim_pos[chrom].get(rsid)
    if bimrow is None:
        mismatch += 1
        continue

    bimval = bims[chrom].iloc[bimrow, 3]      # shorthand: the position column
    qpos   = pos_map.get(rsid)               # O(1) lookup

    if bimval != qpos and last_error != rsid: #makes it so you don't print every repeat!
        qpos_full = subset[subset['rsid'] == rsid].iloc[0]
        qpos_pos = (qpos_full['chromosome'], qpos_full['position'], qpos_full['ref'], qpos_full['alt'])
        bimval_full = bims[chrom].iloc[bimrow]
        print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_pos}", sep = ' ')
        last_error = rsid
        all_mismatch.append((rsid, bimval_full, qpos_full))
    elif bimval == qpos and last_error != rsid:
        matched += 1
        # break
print(matched)
# Out:
# ...
#   3%|▎         | 25883/997133 [00:00<00:08, 117488.25it/s]
# Mismatch at rsid rs550285297: 108031 != 108030.
#  Bimval: 0              1
# 1    rs550285297
# 2            0.0
# 3         108031
# 4              T
# 5              G
# Name: 72, dtype: object
#  Qpos: (1, 108030, 'G', 'T')
#  13%|█▎        | 133508/997133 [00:01<00:07, 120582.52it/s]
# Mismatch at rsid rs4648606: 1715983 != 1648826.
#  Bimval: 0            1
# 1    rs4648606
# 2     1.510234
# 3      1715983
# 4            G
# 5            A
# Name: 4325, dtype: object
#  Qpos: (1, 1648826, 'A', 'G')
#  51%|█████     | 504032/997133 [00:04<00:04, 111271.37it/s]
# Mismatch at rsid rs1298192: 8802340 != 8802339.
#  Bimval: 0            1
# 1    rs1298192
# 2    17.940961
# 3      8802340
# 4            C
# 5            T
# Name: 34246, dtype: object
#  Qpos: (1, 8802339, 'C', 'T')
# Mismatch at rsid rs1325920: 8879784 != 8879783.
#  Bimval: 0            1
# 1    rs1325920
# 2    17.984289
# 3      8879784
# ...

# %%
all_mismatch[0]
# Out:
# ('rs550285297',
#  0              1
#  1    rs550285297
#  2            0.0
#  3         108031
#  4              T
#  5              G
#  Name: 72, dtype: object,
#  molecular_trait_id                Interval_1
#  chromosome                                 1
#  position                              108030
#  ref                                        G
#  alt                                        T
#  variant                      chr1_108030_G_T
#  ma_samples                                 8
#  maf                                 0.043956
#  pvalue                              0.714561
#  beta                               -0.122386
#  se                                  0.333399
#  type                                     SNP
#  ac                                         8
#  an                                       182
#  r2                                       NaN
#  molecular_trait_object_id         Interval_1
#  gene_id                           Interval_1
# ...

# %%
for mismatch in all_mismatch:
    rsid, bimval_full, qpos_full = mismatch
    pos1 = bimval_full[3]-1
    pos2 = qpos_full['position']-1
    print(f"expected reference value: {qpos_full['ref']}, expected alternate value: {qpos_full['alt']}")
    print(f"value from bim: {genome['chr1'][pos1]-7}, value from qpos: {genome['chr1'][pos2]-7}")
# Out:
# expected reference value: G, expected alternate value: T
# value from bim: 3, value from qpos: 2
# expected reference value: A, expected alternate value: G
# value from bim: 2, value from qpos: 0
# expected reference value: C, expected alternate value: T
# value from bim: 2, value from qpos: 1
# expected reference value: G, expected alternate value: A
# value from bim: 0, value from qpos: 2
# expected reference value: G, expected alternate value: A
# value from bim: 2, value from qpos: 2
# expected reference value: G, expected alternate value: A
# value from bim: 3, value from qpos: 2
# expected reference value: G, expected alternate value: T
# value from bim: 1, value from qpos: 2
# expected reference value: A, expected alternate value: G
# value from bim: 0, value from qpos: 0
# expected reference value: A, expected alternate value: G
# value from bim: 1, value from qpos: 0
# expected reference value: A, expected alternate value: G
# value from bim: 3, value from qpos: 0

# %%
#wasn't the first one fine?
for mismatch in all_mismatch:
    rsid, bimval_full, qpos_full = mismatch
    pos1 = bimval_full[3]-1
    pos2 = qpos_full['position']-1
    break
print(pos1,pos2)
print('reference:', qpos_full['ref'])
print('alternate:', qpos_full['alt'])
genome['chr1'][pos2:pos2+3] #this is the one that was wrong, so let's see if it's actually a mismatch. Huh, clealry pos 2 doesn't match here, this is just one exception I guess...
#a ton of them match tho, do they disagree with the reference genome? It's giving a C for some reason here, wtf??
# Out:
# 108030 108029
# reference: G
# alternate: T
# array([ 9, 10, 10], dtype=int8)

# %%
rsid, bimval_full, qpos_full = all_mismatch[1]
pos1 = bimval_full[3]-1
pos2 = qpos_full['position']-1
print(bimval_full)

print(pos1,pos2)
print('reference:', qpos_full['ref'])
print('alternate:', qpos_full['alt'])
genome['chr1'][pos1:pos1+5], genome['chr1'][pos2] #if we go by reference, then this could be correct, idk why differ tho...
# Out:
# 0            1
# 1    rs4648606
# 2     1.510234
# 3      1715983
# 4            G
# 5            A
# Name: 4325, dtype: object
# 1715982 1648825
# reference: A
# alternate: G
# (array([ 9, 10,  7,  9,  8], dtype=int8), 7)

# %%
rsid, bimval_full, qpos_full = all_mismatch[2]
pos1 = bimval_full[3]-1
pos2 = qpos_full['position']-1
print(bimval_full)

print(pos1,pos2) #another case of off by 1, but which is reference, which is alternate?
print('reference:', qpos_full['ref'])
print('alternate:', qpos_full['alt'])
genome['chr1'][pos1], genome['chr1'][pos2]
# Out:
# 0            1
# 1    rs1298192
# 2    17.940961
# 3      8802340
# 4            C
# 5            T
# Name: 34246, dtype: object
# 8802339 8802338
# reference: C
# alternate: T
# (9, 8)

# %%
rsid, bimval_full, qpos_full = all_mismatch[3]
pos1 = bimval_full[3]-1
pos2 = qpos_full['position']-1
print(bimval_full)

print(pos1,pos2) #another case of off by 1, but which is reference, which is alternate?
print('reference:', qpos_full['ref'])
print('alternate:', qpos_full['alt'])
genome['chr1'][pos1], genome['chr1'][pos2]
#same thing again, guess that they agree on alternate and reference, but sometimes there's mismatch of which nucleotide and which direction it is mutated... isn't that a big deal?
# Out:
# 0            1
# 1    rs1325920
# 2    17.984289
# 3      8879784
# 4            G
# 5            A
# Name: 34414, dtype: object
# 8879783 8879782
# reference: G
# alternate: A
# (7, 9)

# %%
rsid, bimval_full, qpos_full = all_mismatch[4]
pos1 = bimval_full[3]-1
pos2 = qpos_full['position']-1
print(bimval_full)

print(pos1,pos2) #another case of off by 1, but which is reference, which is alternate?
print('reference:', qpos_full['ref'])
print('alternate:', qpos_full['alt'])
genome['chr1'][pos1], genome['chr1'][pos2]
#here it's just a difference of 2 values
# Out:
# 0              1
# 1    rs367644024
# 2      26.796564
# 3       13376388
# 4              A
# 5              G
# Name: 49624, dtype: object
# 13376387 13376385
# reference: G
# alternate: A
# (9, 9)

# %%
rsid, bimval_full, qpos_full = all_mismatch[5]
pos1 = bimval_full[3]-1
pos2 = qpos_full['position']-1
print(bimval_full)

print(pos1,pos2) #another case of off by 1, but which is reference, which is alternate?
print('reference:', qpos_full['ref'])
print('alternate:', qpos_full['alt'])
genome['chr1'][pos1], genome['chr1'][pos2]
# Out:
# 0            1
# 1    rs2359299
# 2    26.797922
# 3        13802
# 4            G
# 5            T
# Name: 49626, dtype: object
# 13801 13377098
# reference: G
# alternate: A
# (10, 9)

# %%
#this one is just bad... why is it so off??
bimval_full
# Out:
# 0            1
# 1    rs2359299
# 2    26.797922
# 3        13802
# 4            G
# 5            T
# Name: 49626, dtype: object

# %%
qpos_full

#I straight up think this is wrong...
# Out:
# molecular_trait_id                Interval_598
# chromosome                                   1
# position                              13377099
# ref                                          G
# alt                                          A
# variant                      chr1_13377099_G_A
# ma_samples                                  38
# maf                                   0.236264
# pvalue                                0.132686
# beta                                  0.181193
# se                                    0.119231
# type                                       SNP
# ac                                          43
# an                                         182
# r2                                         NaN
# molecular_trait_object_id         Interval_598
# gene_id                           Interval_598
# median_tpm                                 NaN
# rsid                                 rs2359299
# Name: 824424, dtype: object

# %%
#so what we can do is sest up more forgiving test
mismatch = 0
last_error=None
all_mismatch = []
for rsid in tqdm(rsids):
    bimrow = bim_pos[chrom].get(rsid)
    if bimrow is None:
        mismatch += 1
        continue

    bimval = bims[chrom].iloc[bimrow, 3]      # shorthand: the position column
    qpos   = pos_map.get(rsid)               # O(1) lookup

    if bimval != qpos:
        if abs(bimval-qpos) > 5: #another issue if not close
            print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            all_mismatch.append((rsid, bimval_full, qpos_full))
            continue
        qpos_full = subset[subset['rsid'] == rsid].iloc[0]
        bimval_full = bims[chrom].iloc[bimrow]
        condition1 = (qpos_full['ref'] == bimval_full[4]) and qpos_full['alt'] == bimval_full[5]
        condition2 = (qpos_full['ref'] == bimval_full[5]) and qpos_full['alt'] == bimval_full[4]
        if not (condition1 or condition2):
            print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            all_mismatch.append((rsid, bimval_full, qpos_full))
# Out:
# ...
#  12%|█▏        | 122185/997133 [00:01<00:07, 122279.98it/s]
# Mismatch at rsid rs4648606: 1715983 != 1648826.
#  Bimval: 0              1
# 1    rs550285297
# 2            0.0
# 3         108031
# 4              T
# 5              G
# Name: 72, dtype: object
#  Qpos: molecular_trait_id                Interval_1
# chromosome                                 1
# position                              108030
# ref                                        G
# alt                                        T
# variant                      chr1_108030_G_T
# ma_samples                                 8
# maf                                 0.043956
# pvalue                              0.714561
# beta                               -0.122386
# se                                  0.333399
# type                                     SNP
# ac                                         8
# an                                       182
# r2                                       NaN
# ...

# %%
#we expect at least 1 example
all_mismatch
# Out:
# [('rs4648606',
#   0              1
#   1    rs550285297
#   2            0.0
#   3         108031
#   4              T
#   5              G
#   Name: 72, dtype: object,
#   molecular_trait_id                Interval_1
#   chromosome                                 1
#   position                              108030
#   ref                                        G
#   alt                                        T
#   variant                      chr1_108030_G_T
#   ma_samples                                 8
#   maf                                 0.043956
#   pvalue                              0.714561
#   beta                               -0.122386
#   se                                  0.333399
#   type                                     SNP
#   ac                                         8
#   an                                       182
#   r2                                       NaN
#   molecular_trait_object_id         Interval_1
# ...

# %%
print(len(all_mismatch)) #so we have multiple examples, let's see them
rsid, bimval_full, qpos_full = all_mismatch[0]
pos1 = bimval_full[3]-1
pos2 = qpos_full['position']-1
print(bimval_full)

print(pos1,pos2) #another case of off by 1, but which is reference, which is alternate?
print('reference:', qpos_full['ref'])
print('alternate:', qpos_full['alt'])
genome['chr1'][pos1], genome['chr1'][pos2]
#ref and alternate literally disagree...
# Out:
# 28
# 0              1
# 1    rs550285297
# 2            0.0
# 3         108031
# 4              T
# 5              G
# Name: 72, dtype: object
# 108030 108029
# reference: G
# alternate: T
# (10, 9)

# %%
#this should not be a problem, the locations are close...

rsid, bimval_full, qpos_full = all_mismatch[1]
pos1 = bimval_full[3]-1
pos2 = qpos_full['position']-1
print(bimval_full)

print(pos1,pos2) #another case of off by 1, but which is reference, which is alternate?
print('reference:', qpos_full['ref'])
print('alternate:', qpos_full['alt'])
genome['chr1'][pos1], genome['chr1'][pos2]
# Out:
# 0              1
# 1    rs550285297
# 2            0.0
# 3         108031
# 4              T
# 5              G
# Name: 72, dtype: object
# 108030 108029
# reference: G
# alternate: T
# (10, 9)

# %%
qpos_full
# Out:
# molecular_trait_id                Interval_1
# chromosome                                 1
# position                              108030
# ref                                        G
# alt                                        T
# variant                      chr1_108030_G_T
# ma_samples                                 8
# maf                                 0.043956
# pvalue                              0.714561
# beta                               -0.122386
# se                                  0.333399
# type                                     SNP
# ac                                         8
# an                                       182
# r2                                       NaN
# molecular_trait_object_id         Interval_1
# gene_id                           Interval_1
# median_tpm                               NaN
# rsid                             rs550285297
# Name: 845, dtype: object

# %%
qpos = pos_map.get(rsid)
print(qpos)
print(bimval_full[3])
# Out:
# 1648826
# 108031

# %%
rsid
# Out:
# 'rs4648606'

# %%
#here we see an issue with pos map...
all_caqtl[all_caqtl['rsid'] == rsid]
# Out:
#        molecular_trait_id  chromosome  position ref alt           variant  \
# 108569       Interval_100           1   1648826   A   G  chr1_1648826_A_G
# 108570        Interval_77           1   1648826   A   G  chr1_1648826_A_G
# 108571        Interval_78           1   1648826   A   G  chr1_1648826_A_G
# 108572        Interval_79           1   1648826   A   G  chr1_1648826_A_G
# 108573        Interval_80           1   1648826   A   G  chr1_1648826_A_G
# 108574        Interval_81           1   1648826   A   G  chr1_1648826_A_G
# 108575        Interval_82           1   1648826   A   G  chr1_1648826_A_G
# 108576        Interval_83           1   1648826   A   G  chr1_1648826_A_G
# 108577        Interval_84           1   1648826   A   G  chr1_1648826_A_G
# 108578        Interval_85           1   1648826   A   G  chr1_1648826_A_G
# 108579        Interval_86           1   1648826   A   G  chr1_1648826_A_G
# 108580        Interval_87           1   1648826   A   G  chr1_1648826_A_G
# ...

# %%
#clealry the rsid is an issue...
#wait found an issue
#so what we can do is sest up more forgiving test
mismatch = 0
last_error=None
all_mismatch = []
for rsid in tqdm(rsids):
    bimrow = bim_pos[chrom].get(rsid)
    if bimrow is None:
        mismatch += 1
        continue

    bimval = bims[chrom].iloc[bimrow, 3]      # shorthand: the position column
    qpos   = pos_map.get(rsid)               # O(1) lookup

    if bimval != qpos:
        qpos_full = subset[subset['rsid'] == rsid].iloc[0]
        bimval_full = bims[chrom].iloc[bimrow]
        if abs(bimval-qpos) > 5: #another issue if not close
            print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            all_mismatch.append((rsid, bimval_full, qpos_full))
            continue
        condition1 = (qpos_full['ref'] == bimval_full[4]) and qpos_full['alt'] == bimval_full[5]
        condition2 = (qpos_full['ref'] == bimval_full[5]) and qpos_full['alt'] == bimval_full[4]
        if not (condition1 or condition2):
            print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            all_mismatch.append((rsid, bimval_full, qpos_full))
# Out:
#  11%|█         | 108009/997133 [00:01<00:08, 101873.29it/s]
# Mismatch at rsid rs4648606: 1715983 != 1648826.
#  Bimval: 0            1
# 1    rs4648606
# 2     1.510234
# 3      1715983
# 4            G
# 5            A
# Name: 4325, dtype: object
#  Qpos: molecular_trait_id               Interval_100
# chromosome                                  1
# position                              1648826
# ref                                         A
# alt                                         G
# variant                      chr1_1648826_A_G
# ma_samples                                 53
# maf                                  0.340659
# pvalue                               0.241455
# beta                                 0.154361
# se                                   0.130765
# type                                      SNP
# ac                                         62
# an                                        182
# r2                                        NaN
# ...

# %%
rsid, bimval_full, qpos_full = all_mismatch[1]
pos1 = bimval_full[3]-1
pos2 = qpos_full['position']-1
print(bimval_full)

print(pos1,pos2) #another case of off by 1, but which is reference, which is alternate?
print('reference:', qpos_full['ref'])
print('alternate:', qpos_full['alt'])
genome['chr1'][pos1], genome['chr1'][pos2]
#so here they're just far away, but total is 1 million and only 28 total like this
# Out:
# 0            1
# 1    rs4648606
# 2     1.510234
# 3      1715983
# 4            G
# 5            A
# Name: 4325, dtype: object
# 1715982 1648825
# reference: A
# alternate: G
# (9, 7)

# %%
#let's generate more comprehensive way to test
mismatch = 0
last_error=None
mismatch_size = []
mismatch_values = []
for rsid in tqdm(rsids):
    bimrow = bim_pos[chrom].get(rsid)
    if bimrow is None:
        mismatch += 1
        continue

    bimval = bims[chrom].iloc[bimrow, 3]      # shorthand: the position column
    qpos   = pos_map.get(rsid)               # O(1) lookup

    if bimval != qpos:
        qpos_full = subset[subset['rsid'] == rsid].iloc[0]
        bimval_full = bims[chrom].iloc[bimrow]
        if abs(bimval-qpos) > 5: #another issue if not close
            # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            mismatch_size.append((rsid, bimval_full, qpos_full))
        condition1 = (qpos_full['ref'] == bimval_full[4]) and qpos_full['alt'] == bimval_full[5]
        condition2 = (qpos_full['ref'] == bimval_full[5]) and qpos_full['alt'] == bimval_full[4]
        if not (condition1 or condition2):
            # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            mismatch_values.append((rsid, bimval_full, qpos_full))
            
print(f"Missing rsids: {mismatch}")
print(f"Mismatch size: {len(mismatch_size)}")
print(f"Mismatch values: {len(mismatch_values)}")
# Out:
# ...
# 100%|██████████| 997133/997133 [00:12<00:00, 77496.14it/s]
# Missing rsids: 342224
# Mismatch size: 28
# Mismatch values: 2

# %%
rsid, bimval_full, qpos_full = mismatch_values[1]
pos1 = bimval_full[3]-1
pos2 = qpos_full['position']-1
print(bimval_full)

print(pos1,pos2) #another case of off by 1, but which is reference, which is alternate?
print('reference:', qpos_full['ref'])
print('alternate:', qpos_full['alt'])
genome['chr1'][pos1], genome['chr1'][pos2]

#this one is like really bad!
# Out:
# 0            1
# 1    rs2359299
# 2    26.797922
# 3        13802
# 4            G
# 5            T
# Name: 49626, dtype: object
# 13801 13377098
# reference: G
# alternate: A
# (10, 9)

# %% [markdown]
# # checking whoel dataset

# %%
#now redo this with polars!

import polars as pl
all_caqtl = pl.scan_csv('/data1/lesliec/sarthak/data/joint_playground/caQTL/QTD100018.all.tsv', separator='\t')

# %%
unique = all_caqtl.unique(subset="rsid", maintain_order=True)
unique = unique.collect()

# %%
unique.shape #only like 10 million now, because we removed all replicates...
# Out:
# (9489655, 19)

# %%
unique
# Out:
# shape: (9_489_655, 19)
# ┌────────────┬────────────┬───────────┬─────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ molecular_ ┆ chromosome ┆ position  ┆ ref ┆ … ┆ molecular_ ┆ gene_id    ┆ median_tpm ┆ rsid      │
# │ trait_id   ┆ ---        ┆ ---       ┆ --- ┆   ┆ trait_obje ┆ ---        ┆ ---        ┆ ---       │
# │ ---        ┆ i64        ┆ i64       ┆ str ┆   ┆ ct_id      ┆ str        ┆ str        ┆ str       │
# │ str        ┆            ┆           ┆     ┆   ┆ ---        ┆            ┆            ┆           │
# │            ┆            ┆           ┆     ┆   ┆ str        ┆            ┆            ┆           │
# ╞════════════╪════════════╪═══════════╪═════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ Interval_1 ┆ 1          ┆ 10583     ┆ G   ┆ … ┆ Interval_1 ┆ Interval_1 ┆ NA         ┆ rs5810814 │
# │            ┆            ┆           ┆     ┆   ┆            ┆            ┆            ┆ 0         │
# ...

# %%
#remove the rows if 'type' == 'INDEL'
unique = unique.filter(pl.col('type') != 'INDEL')
unique = unique.filter(pl.col('rsid').is_not_null())
unique
# Out:
# shape: (6_930_949, 19)
# ┌────────────┬────────────┬───────────┬─────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ molecular_ ┆ chromosome ┆ position  ┆ ref ┆ … ┆ molecular_ ┆ gene_id    ┆ median_tpm ┆ rsid      │
# │ trait_id   ┆ ---        ┆ ---       ┆ --- ┆   ┆ trait_obje ┆ ---        ┆ ---        ┆ ---       │
# │ ---        ┆ i64        ┆ i64       ┆ str ┆   ┆ ct_id      ┆ str        ┆ str        ┆ str       │
# │ str        ┆            ┆           ┆     ┆   ┆ ---        ┆            ┆            ┆           │
# │            ┆            ┆           ┆     ┆   ┆ str        ┆            ┆            ┆           │
# ╞════════════╪════════════╪═══════════╪═════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ Interval_1 ┆ 1          ┆ 10583     ┆ G   ┆ … ┆ Interval_1 ┆ Interval_1 ┆ NA         ┆ rs5810814 │
# │            ┆            ┆           ┆     ┆   ┆            ┆            ┆            ┆ 0         │
# ...

# %%
#now down to 7 million!
#now create the mapping of rsid to position
pos_map = dict(zip(unique['rsid'], unique['position'])) #I guess assume rsid only has one position
pos_map
# Out:
# {'rs58108140': 10583,
#  'rs879707275': 13649,
#  'rs879805273': 13757,
#  'rs796086906': 13868,
#  'rs546169444': 14464,
#  'rs1385614989': 14470,
#  'rs199856693': 14933,
#  'rs1171100045': 15112,
#  'rs201635489': 15447,
#  'rs62636367': 16719,
#  'rs62636368': 16841,
#  'rs3891260': 16856,
#  'rs199745162': 16949,
#  'rs201833382': 17005,
#  'rs199740902': 17020,
#  'rs867691030': 17147,
#  'rs200978805': 17222,
#  'rs369606208': 17365,
#  'rs754322362': 17379,
#  'rs201535981': 17385,
#  'rs372841554': 17407,
#  'rs747093451': 17408,
#  'rs200503540': 17452,
#  'rs374545136': 17556,
#  'rs71260069': 17697,
#  'rs376731495': 17722,
#  'rs1190943651': 17730,
#  'rs867399458': 17928,
#  'rs767055815': 17929,
#  'rs879518682': 19217,
#  'rs1254205006': 19248,
#  'rs796202720': 20184,
#  'rs3950648': 20227,
#  'rs1407743745': 20231,
#  'rs11490226': 20250,
#  'rs796745295': 29368,
#  'rs867555950': 30809,
#  'rs879538668': 39203,
#  'rs1342104522': 39224,
#  'rs11489801': 39230,
# ...

# %%
len(pos_map) #correct length!
# Out:
# 6930949

# %%
#load in bims
import pandas as pd

bims = {}
for i in range(1,23):
    bim_path = f'/data1/deyk/extras/1000G_BIMS_hg38/1000G.EUR.QC.{i}.bim'
    bim = pd.read_csv(bim_path, sep='\t', header=None)
    bims[i] = bim


bim_pos = {
    chrom: dict(zip(bims[chrom][1].values, bims[chrom][3].index))
    for chrom in bims
}

# %%
rsids = unique['rsid'].to_numpy()
len(rsids)
# Out:
# 6930949

# %%
#now let's do our loop with bims
from tqdm import tqdm
mismatch = 0
last_error=None
mismatch_size = []
mismatch_values = []
for rsid in tqdm(rsids):
    chrom = unique
    bimrow = bim_pos[chrom].get(rsid)
    if bimrow is None:
        mismatch += 1
        continue

    bimval = bims[chrom].iloc[bimrow, 3]      # shorthand: the position column
    qpos   = pos_map.get(rsid)               # O(1) lookup

    if bimval != qpos:
        qpos_full = subset[subset['rsid'] == rsid].iloc[0]
        bimval_full = bims[chrom].iloc[bimrow]
        if abs(bimval-qpos) > 5: #another issue if not close
            # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            mismatch_size.append((rsid, bimval_full, qpos_full))
        condition1 = (qpos_full['ref'] == bimval_full[4]) and qpos_full['alt'] == bimval_full[5]
        condition2 = (qpos_full['ref'] == bimval_full[5]) and qpos_full['alt'] == bimval_full[4]
        if not (condition1 or condition2):
            # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            mismatch_values.append((rsid, bimval_full, qpos_full))
            
print(f"Missing rsids: {mismatch}")
print(f"Mismatch size: {len(mismatch_size)}")
print(f"Mismatch values: {len(mismatch_values)}")
# Out:
#   0%|          | 0/6930949 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 8
#       6 mismatch_values = []
#       7 for rsid in tqdm(rsids):
# ----> 8     bimrow = bim_pos[chrom].get(rsid)
#       9     if bimrow is None:
#      10         mismatch += 1
#
# NameError: name 'chrom' is not defined

# %%
rsid
# Out:
# 'rs58108140'

# %%
pos_map[rsid] #this is the position of the genome, not the actual thing we wanat
# Out:
# 10583

# %%
unique.filter(pl.col('rsid') == rsid)
# Out:
# shape: (1, 19)
# ┌────────────┬────────────┬──────────┬─────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ molecular_ ┆ chromosome ┆ position ┆ ref ┆ … ┆ molecular_ ┆ gene_id    ┆ median_tpm ┆ rsid       │
# │ trait_id   ┆ ---        ┆ ---      ┆ --- ┆   ┆ trait_obje ┆ ---        ┆ ---        ┆ ---        │
# │ ---        ┆ i64        ┆ i64      ┆ str ┆   ┆ ct_id      ┆ str        ┆ str        ┆ str        │
# │ str        ┆            ┆          ┆     ┆   ┆ ---        ┆            ┆            ┆            │
# │            ┆            ┆          ┆     ┆   ┆ str        ┆            ┆            ┆            │
# ╞════════════╪════════════╪══════════╪═════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ Interval_1 ┆ 1          ┆ 10583    ┆ G   ┆ … ┆ Interval_1 ┆ Interval_1 ┆ NA         ┆ rs58108140 │
# └────────────┴────────────┴──────────┴─────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
#now let's do our loop with bims
from tqdm import tqdm
mismatch = 0
last_error=None
mismatch_size = []
mismatch_values = []
for i,rsid in tqdm(enumerate(rsids)):
    chrom = unique[i]['chromosome'][0]
    bimrow = bim_pos[chrom].get(rsid)
    if bimrow is None:
        mismatch += 1
        continue

    bimval = bims[chrom].iloc[bimrow, 3]      # shorthand: the position column
    qpos   = pos_map.get(rsid)               # O(1) lookup

    if bimval != qpos:
        qpos_full = unique[i]
        bimval_full = bims[chrom].iloc[bimrow]
        if abs(bimval-qpos) > 5: #another issue if not close
            # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            mismatch_size.append((rsid, bimval_full, qpos_full))
        condition1 = (qpos_full['ref'] == bimval_full[4]) and qpos_full['alt'] == bimval_full[5]
        condition2 = (qpos_full['ref'] == bimval_full[5]) and qpos_full['alt'] == bimval_full[4]
        if not (condition1 or condition2):
            # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            mismatch_values.append((rsid, bimval_full, qpos_full))
            
print(f"Missing rsids: {mismatch}")
print(f"Mismatch size: {len(mismatch_size)}")
print(f"Mismatch values: {len(mismatch_values)}")
# Out:
# 110it [00:00, 77036.81it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 23
#      20 if abs(bimval-qpos) > 5: #another issue if not close
#      21     # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
#      22     mismatch_size.append((rsid, bimval_full, qpos_full))
# ---> 23 condition1 = (qpos_full['ref'] == bimval_full[4]) and qpos_full['alt'] == bimval_full[5]
#      24 condition2 = (qpos_full['ref'] == bimval_full[5]) and qpos_full['alt'] == bimval_full[4]
#      25 if not (condition1 or condition2):
#      26     # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
#
# File /data1/lesliec/sarthak/caduceus/.pixi/envs/default/lib/python3.11/site-packages/polars/series/series.py:561, in Series.__bool__(self)
# ...

# %%
#first check if we are enumerating right
print(rsid)
print(i)
unique[i]
#ok this looks good!
# Out:
# rs550285297
# 110
# shape: (1, 19)
# ┌────────────┬────────────┬──────────┬─────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ molecular_ ┆ chromosome ┆ position ┆ ref ┆ … ┆ molecular_ ┆ gene_id    ┆ median_tpm ┆ rsid       │
# │ trait_id   ┆ ---        ┆ ---      ┆ --- ┆   ┆ trait_obje ┆ ---        ┆ ---        ┆ ---        │
# │ ---        ┆ i64        ┆ i64      ┆ str ┆   ┆ ct_id      ┆ str        ┆ str        ┆ str        │
# │ str        ┆            ┆          ┆     ┆   ┆ ---        ┆            ┆            ┆            │
# │            ┆            ┆          ┆     ┆   ┆ str        ┆            ┆            ┆            │
# ╞════════════╪════════════╪══════════╪═════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ Interval_1 ┆ 1          ┆ 108030   ┆ G   ┆ … ┆ Interval_1 ┆ Interval_1 ┆ NA         ┆ rs55028529 │
# │            ┆            ┆          ┆     ┆   ┆            ┆            ┆            ┆ 7          │
# ...

# %%
qpos_full['chromosome'].item()
# Out:
# 1

# %%
#now let's do our loop with bims
from tqdm import tqdm
mismatch = 0
last_error=None
mismatch_size = []
mismatch_values = []
for i,rsid in tqdm(enumerate(rsids)):
    chrom = unique[i]['chromosome'][0]
    bimrow = bim_pos[chrom].get(rsid)
    if bimrow is None:
        mismatch += 1
        continue

    bimval = bims[chrom].iloc[bimrow, 3]      # shorthand: the position column
    qpos   = pos_map.get(rsid)               # O(1) lookup

    if bimval != qpos:
        qpos_full = unique[i]
        bimval_full = bims[chrom].iloc[bimrow]
        if abs(bimval-qpos) > 5: #another issue if not close
            # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            mismatch_size.append((rsid, bimval_full, qpos_full))
        condition1 = (qpos_full['ref'].item() == bimval_full[4]) and qpos_full['alt'].item() == bimval_full[5]
        condition2 = (qpos_full['ref'].item() == bimval_full[5]) and qpos_full['alt'].item() == bimval_full[4]
        if not (condition1 or condition2):
            # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            mismatch_values.append((rsid, bimval_full, qpos_full))
            
print(f"Missing rsids: {mismatch}")
print(f"Mismatch size: {len(mismatch_size)}")
print(f"Mismatch values: {len(mismatch_values)}")
# Out:
# 6930949it [02:38, 43784.56it/s]
# Missing rsids: 421332
# Mismatch size: 1230
# Mismatch values: 820

# %%
#this is relatively fast, but so many iterations it will take a while lol

#these numbers are reasonable

rsids_mismatch_size = [mismatch[0] for mismatch in mismatch_size]
rsids_mismatch_values = [mismatch[0] for mismatch in mismatch_values]

overlap = 0
for rsid in rsids_mismatch_size:
    if rsid in rsids_mismatch_values:
        overlap += 1
print(f"Overlap: {overlap}")
# Out:
# Overlap: 814

# %%
diff_list = []
for mismatch in mismatch_size:
    rsid, bimval_full, qpos_full = mismatch
    pos1 = bimval_full[3]-1
    pos2 = qpos_full['position'].item()-1
    diff_list.append(abs(pos1-pos2))

# %%
import numpy as np
import matplotlib.pyplot as plt

diff_array = np.array(diff_list)

plt.figure(figsize=(8, 5))
plt.hist(diff_array, bins=100)
# plt.xscale("log")      # ← uncomment for log‑scale x‑axis
# bins = np.logspace(np.log10(diff_array[diff_array>0].min()),
#                    np.log10(diff_array.max()), 100)
# plt.clf(); plt.hist(diff_array, bins=bins)  # use these lines instead if you want log‑spaced bins

plt.xlabel("Difference")
plt.ylabel("Frequency")
plt.title("Distribution of Differences")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # final thing, verify that rsids match

# %%
#easiest to do this go one line at a time
# all_caqtl = pl.scan_csv('/data1/lesliec/sarthak/data/joint_playground/caQTL/QTD100018.all.tsv', separator='\t')
tsv_file = '/data1/lesliec/sarthak/data/joint_playground/caQTL/QTD100018.all.tsv'
rsids = {}
with open(tsv_file, 'r') as file:
    next(file)  # Skip the header line
    for line in file:
        line = line.strip()
        line = line.split('\t')
        print(line)

        rsid = line[-1]

        if rsid not in rsids:
            rsids[rsid] = line
        else: #verify that the important information matches
            assert rsids[rsid][1] == line[1], f"chroms don't match {rsid}: {rsids[rsid][1]} != {line[1]}"
            assert rsids[rsid][2] == line[2], f"positions don't match {rsid}: {rsids[rsid][2]} != {line[2]}"
            assert rsids[rsid][3] == line[3], f"ref don't match {rsid}: {rsids[rsid][3]} != {line[3]}"
            assert rsids[rsid][4] == line[4], f"alt don't match {rsid}: {rsids[rsid][4]} != {line[4]}"
            assert rsids[rsid][5] == line[5], f"variant don't match {rsid}: {rsids[rsid][5]} != {line[5]}"
            assert rsids[rsid][11] == line[11], f"type don't match {rsid}: {rsids[rsid][11]} != {line[11]}"

        break  # Remove this line to process all lines
# Out:
# ['Interval_1', '1', '10583', 'G', 'A', 'chr1_10583_G_A', '9', '0.0494506', '0.861729', '-0.0525099', '0.300473', 'SNP', '9', '182', 'NA', 'Interval_1', 'Interval_1', 'NA', 'rs58108140']

# %%
from tqdm import tqdm
tsv_file = '/data1/lesliec/sarthak/data/joint_playground/caQTL/QTD100018.all.tsv'
rsids = {}
issues = []
with open(tsv_file, 'r') as file:
    next(file)  # Skip the header line
    for line in tqdm(file, total=350_000_000):
        line = line.strip()
        line = line.split('\t')
        # print(line)

        rsid = line[-1]

        if rsid not in rsids:
            rsids[rsid] = line
        else: #verify that the important information matches
            # assert rsids[rsid][1] == line[1], f"chroms don't match {rsid}: {rsids[rsid][1]} != {line[1]}"
            # assert rsids[rsid][2] == line[2], f"positions don't match {rsid}: {rsids[rsid][2]} != {line[2]}"
            # assert rsids[rsid][3] == line[3], f"ref don't match {rsid}: {rsids[rsid][3]} != {line[3]}"
            # assert rsids[rsid][4] == line[4], f"alt don't match {rsid}: {rsids[rsid][4]} != {line[4]}"
            # assert rsids[rsid][5] == line[5], f"variant don't match {rsid}: {rsids[rsid][5]} != {line[5]}"
            # assert rsids[rsid][11] == line[11], f"type don't match {rsid}: {rsids[rsid][11]} != {line[11]}"
            if rsids[rsid][1] != line[1]:
                # print(f"chroms don't match {rsid}: {rsids[rsid][1]} != {line[1]}")
                issues.append((rsid, 'chrom', rsids[rsid], line))
                continue
            if rsids[rsid][2] != line[2]:
                # print(f"positions don't match {rsid}: {rsids[rsid][2]} != {line[2]}")
                issues.append((rsid, 'chrom', rsids[rsid], line))
                continue
            if rsids[rsid][3] != line[3]:
                # print(f"ref don't match {rsid}: {rsids[rsid][3]} != {line[3]}")
                issues.append((rsid, 'chrom', rsids[rsid], line))
                continue
            if rsids[rsid][4] != line[4]:
                # print(f"alt don't match {rsid}: {rsids[rsid][4]} != {line[4]}")
                issues.append((rsid, 'chrom', rsids[rsid], line))
                continue
            if rsids[rsid][5] != line[5]:
                # print(f"variant don't match {rsid}: {rsids[rsid][5]} != {line[5]}")
                issues.append((rsid, 'chrom', rsids[rsid], line))
                continue
            if rsids[rsid][11] != line[11]:
                # print(f"type don't match {rsid}: {rsids[rsid][11]} != {line[11]}")
                issues.append((rsid, 'chrom', rsids[rsid], line))
                continue
# Out:
# ...
#  99%|█████████▊| 344879633/350000000 [08:45<00:07, 655856.63it/s]

# %%
print(len(issues)) #why, just why?
# Out:
# 6974305

# %%
issues[0] #this is rsid NA, of course it has issues!
# Out:
# ('NA',
#  'chrom',
#  ['Interval_1',
#   '1',
#   '99002',
#   'TA',
#   'T',
#   'chr1_99002_TA_T',
#   '6',
#   '0.032967',
#   '0.467608',
#   '-0.28351',
#   '0.388372',
#   'INDEL',
#   '6',
#   '182',
#   'NA',
#   'Interval_1',
#   'Interval_1',
#   'NA',
#   'NA'],
#  ['Interval_1',
#   '1',
#   '99006',
#   'TA',
#   'T',
#   'chr1_99006_TA_T',
#   '6',
#   '0.032967',
#   '0.467608',
#   '-0.28351',
#   '0.388372',
#   'INDEL',
#   '6',
#   '182',
#   'NA',
#   'Interval_1',
#   'Interval_1',
#   'NA',
#   'NA'])

# %%
for issue in issues:
    print(issue[0])
    print(issue[0] == 'NA')
    break
# Out:
# NA
# False
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
# /tmp/ipykernel_1417891/1126908729.py:3: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   print(issue[0] is 'NA')

# %%
issue[0] == 'NA'
# Out:
# True

# %%
non_issue = 0
for issue in issues:
    if issue[0] == 'NA':
        non_issue += 1
print(non_issue)
# Out:
# 816462

# %%
for issue in issues:
    if issue[0] != 'NA':
        print(issue)
        break
# Out:
# ('rs374587598', 'chrom', ['Interval_10', '1', '788757', 'T', 'TAATGG', 'chr1_788757_T_TAATGG', '61', '0.406593', '0.114361', '0.248144', '0.155381', 'INDEL', '74', '182', 'NA', 'Interval_10', 'Interval_10', 'NA', 'rs374587598'], ['Interval_10', '1', '788757', 'T', 'TAATGGAATGG', 'chr1_788757_T_TAATGGAATGG', '44', '0.274725', '0.43732', '-0.128077', '0.164036', 'INDEL', '50', '182', 'NA', 'Interval_10', 'Interval_10', 'NA', 'rs374587598'])

# %%
#let's also remove indels
non_issue = 0
for issue in issues:
    if issue[0] == 'NA':
        non_issue += 1
        continue
    if issue[2][11] == 'INDEL':
        non_issue += 1
print(non_issue)
#most of them are indels!
#leaves only 200k left, let's check
# Out:
# 6714253

# %%
for issue in issues:
    if issue[0] != 'NA' and issue[2][11] != 'INDEL':
        print(issue)
        break
# Out:
# ('rs61768170', 'chrom', ['Interval_10', '1', '821054', 'G', 'A', 'chr1_821054_G_A', '8', '0.043956', '0.86388', '-0.0631726', '0.367258', 'SNP', '8', '182', 'NA', 'Interval_10', 'Interval_10', 'NA', 'rs61768170'], ['Interval_10', '1', '821054', 'G', 'C', 'chr1_821054_G_C', '20', '0.115385', '0.907381', '0.0257619', '0.220703', 'SNP', '21', '182', 'NA', 'Interval_10', 'Interval_10', 'NA', 'rs61768170'])

# %%
#let's just check to see if the position is right
for issue in issues:
    if issue[0] != 'NA' and issue[2][11] != 'INDEL':
        if issue[2][2] != issue[3][2]:
            print(issue)
            break
#ok so the positions are correct for snps and if it's not NA, this is perfect!!!!!

# %%
non_issue = 0
for issue in issues:
    if issue[0] == 'NA':
        non_issue += 1
        continue
    if issue[2][11] == 'INDEL':
        non_issue += 1
        continue
    if issue[2][2] == issue[3][2]:
        non_issue += 1
        continue
non_issue #we only cared about the position, so this is perfect, glad we can ignore it, mostly idnels that are problems lol
# Out:
# 6974305

# %%
non_issue = 0
for issue in issues:
    if issue[0] == 'NA':
        non_issue += 1
        continue
    # if issue[2][11] == 'INDEL':
    #     non_issue += 1
    #     continue
    if issue[2][2] == issue[3][2]:
        non_issue += 1
        continue
non_issue
#oh indels aren't the problem, it's the fact that ref and alternate differ, this is perfectly fine as we already expected this, our filtering just needed to look at position, the valu ematching could be explained
# Out:
# 6974305

# %% [markdown]
# # see out of the 1200, which ones are actually an issue (since multiple reference vs alternate)

# %%
from tqdm import tqdm
tsv_file = '/data1/lesliec/sarthak/data/joint_playground/caQTL/QTD100018.all.tsv'
rsids = {}
issues = []
with open(tsv_file, 'r') as file:
    next(file)  # Skip the header line
    for line in tqdm(file, total=344_879_633):
        line = line.strip()
        line = line.split('\t')
        # print(line)

        rsid = line[-1]

        if rsid not in rsids:
            rsids[rsid] = line
        else: #verify that the important information matches
            # assert rsids[rsid][1] == line[1], f"chroms don't match {rsid}: {rsids[rsid][1]} != {line[1]}"
            # assert rsids[rsid][2] == line[2], f"positions don't match {rsid}: {rsids[rsid][2]} != {line[2]}"
            # assert rsids[rsid][3] == line[3], f"ref don't match {rsid}: {rsids[rsid][3]} != {line[3]}"
            # assert rsids[rsid][4] == line[4], f"alt don't match {rsid}: {rsids[rsid][4]} != {line[4]}"
            # assert rsids[rsid][5] == line[5], f"variant don't match {rsid}: {rsids[rsid][5]} != {line[5]}"
            # assert rsids[rsid][11] == line[11], f"type don't match {rsid}: {rsids[rsid][11]} != {line[11]}"
            if rsids[rsid][1] != line[1]:
                # print(f"chroms don't match {rsid}: {rsids[rsid][1]} != {line[1]}")
                issues.append((rsid, 'chrom', rsids[rsid], line))
                continue
            if rsids[rsid][2] != line[2]:
                # print(f"positions don't match {rsid}: {rsids[rsid][2]} != {line[2]}")
                issues.append((rsid, 'pos', rsids[rsid], line))
                continue
            if rsids[rsid][3] != line[3]:
                # print(f"ref don't match {rsid}: {rsids[rsid][3]} != {line[3]}")
                issues.append((rsid, 'ref', rsids[rsid], line))
                continue
            if rsids[rsid][4] != line[4]:
                # print(f"alt don't match {rsid}: {rsids[rsid][4]} != {line[4]}")
                issues.append((rsid, 'alt', rsids[rsid], line))
                continue
            if rsids[rsid][5] != line[5]:
                # print(f"variant don't match {rsid}: {rsids[rsid][5]} != {line[5]}")
                issues.append((rsid, 'var', rsids[rsid], line))
                continue
            if rsids[rsid][11] != line[11]:
                # print(f"type don't match {rsid}: {rsids[rsid][11]} != {line[11]}")
                issues.append((rsid, 'type', rsids[rsid], line))
                continue
# Out:
#  99%|█████████▊| 344879633/350000000 [09:28<00:08, 606928.43it/s]

# %%
len(issues)
# Out:
# 6974305

# %%
var_issues = []
non_issue = 0
for issue in issues:
    if issue[0] == 'NA':
        non_issue += 1
        continue
    if issue[2][11] == 'INDEL':
        non_issue += 1
        continue
    if issue[1] == 'ref' or issue[1] == 'alt':
        var_issues.append(issue)
        continue
print(len(var_issues))
print(non_issue)
# Out:
# 260052
# 6714253

# %%
len(var_issues) + non_issue, len(issues) #This is all of them, let's see, now we find the var issue ones which is 260k!
# Out:
# (6974305, 6974305)

# %%
var_issues[0]
# Out:
# ('rs61768170',
#  'alt',
#  ['Interval_10',
#   '1',
#   '821054',
#   'G',
#   'A',
#   'chr1_821054_G_A',
#   '8',
#   '0.043956',
#   '0.86388',
#   '-0.0631726',
#   '0.367258',
#   'SNP',
#   '8',
#   '182',
#   'NA',
#   'Interval_10',
#   'Interval_10',
#   'NA',
#   'rs61768170'],
#  ['Interval_10',
#   '1',
#   '821054',
#   'G',
#   'C',
#   'chr1_821054_G_C',
#   '20',
#   '0.115385',
#   '0.907381',
#   '0.0257619',
#   '0.220703',
#   'SNP',
#   '21',
#   '182',
#   'NA',
#   'Interval_10',
#   'Interval_10',
#   'NA',
#   'rs61768170'])

# %%
#ok so these issues are actualy inconsistencies within the file itself!
#but now we have the list of rsids that have variant issues, now find the ones that have a variant discrepancy, see if they overlap with this

#now redo this with polars!

import polars as pl
all_caqtl = pl.scan_csv('/data1/lesliec/sarthak/data/joint_playground/caQTL/QTD100018.all.tsv', separator='\t')
unique = all_caqtl.unique(subset="rsid", maintain_order=True)
unique = unique.collect()

# %%
print(unique.shape)
unique = unique.filter(pl.col('type') != 'INDEL')
print(unique.shape)
unique = unique.filter(pl.col('rsid').is_not_null())
print(unique.shape)
unique = unique.filter(pl.col('rsid') != 'NA')
print(unique.shape)
# Out:
# (9489655, 19)
# (6930949, 19)
# (6930949, 19)
# (6930949, 19)

# %%
#now down to 7 million!
#now create the mapping of rsid to position
pos_map = dict(zip(unique['rsid'], unique['position'])) #I guess assume rsid only has one position
#load in bims
import pandas as pd

bims = {}
for i in range(1,23):
    bim_path = f'/data1/deyk/extras/1000G_BIMS_hg38/1000G.EUR.QC.{i}.bim'
    bim = pd.read_csv(bim_path, sep='\t', header=None)
    bims[i] = bim


bim_pos = {
    chrom: dict(zip(bims[chrom][1].values, bims[chrom][3].index))
    for chrom in bims
}
rsids = unique['rsid'].to_numpy()
len(rsids)
# Out:
# 6930949

# %%
rsids
# Out:
# array(['rs58108140', 'rs879707275', 'rs879805273', ..., 'rs1386837028',
#        'rs1460832765', 'rs1248605022'], dtype=object)

# %%
import numpy as np
temprsids = np.array(rsids, dtype=str)
starts_rs = np.char.startswith(temprsids, "rs")
rsids[starts_rs].shape #all of them, so there's no more Nans!
# Out:
# (6930949,)

# %%
#now get the subset of 1200

from tqdm import tqdm
mismatch = 0
last_error=None
mismatch_size = []
mismatch_values = []
for i,rsid in tqdm(enumerate(rsids)):
    chrom = unique[i]['chromosome'][0]
    bimrow = bim_pos[chrom].get(rsid)
    if bimrow is None:
        mismatch += 1
        continue

    bimval = bims[chrom].iloc[bimrow, 3]      # shorthand: the position column
    qpos   = pos_map.get(rsid)               # O(1) lookup

    if bimval != qpos:
        qpos_full = unique[i]
        bimval_full = bims[chrom].iloc[bimrow]
        if abs(bimval-qpos) > 5: #another issue if not close
            # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            mismatch_size.append((rsid, bimval_full, qpos_full))
        condition1 = (qpos_full['ref'].item() == bimval_full[4]) and qpos_full['alt'].item() == bimval_full[5]
        condition2 = (qpos_full['ref'].item() == bimval_full[5]) and qpos_full['alt'].item() == bimval_full[4]
        if not (condition1 or condition2):
            # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            mismatch_values.append((rsid, bimval_full, qpos_full))
            
print(f"Missing rsids: {mismatch}")
print(f"Mismatch size: {len(mismatch_size)}")
print(f"Mismatch values: {len(mismatch_values)}")
# Out:
# 6930949it [02:39, 43335.95it/s]
# Missing rsids: 421332
# Mismatch size: 1230
# Mismatch values: 820

# %%
rsids_mismatch_values = [mismatch[0] for mismatch in mismatch_values]
rsids_mismatch_values_full = [var_issue[0] for var_issue in var_issues]
print(len(rsids_mismatch_values), len(rsids_mismatch_values_full))
# Out:
# 820 260052

# %%
overlap = 0
for rsid in rsids_mismatch_values:
    if rsid in rsids_mismatch_values_full:
        overlap += 1
overlap
#ok so there's like no overlap here lmfao!
# Out:
# 3

# %%
#final thing to check is mimsmatch size and see how manyy are super close by...

# %%
#So keyy ideas are we can just use all these ones, but exclude the ones with multiple variants and positions that differ a lot from the bims, so minus 1200. Then we can save this subset
unique.shape
# Out:
# (6930949, 19)

# %%
last_error=None
mismatch = []
for i,rsid in tqdm(enumerate(rsids)):
    chrom = unique[i]['chromosome'][0]
    bimrow = bim_pos[chrom].get(rsid)
    if bimrow is None:
        mismatch.append((rsid, 'missing'))
        continue

    bimval = bims[chrom].iloc[bimrow, 3]      # shorthand: the position column
    qpos   = pos_map.get(rsid)               # O(1) lookup

    if bimval != qpos:
        qpos_full = unique[i]
        bimval_full = bims[chrom].iloc[bimrow]
        if abs(bimval-qpos) > 1: #another issue if not close
            # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            mismatch.append((rsid, 'position'))
        condition1 = (qpos_full['ref'].item() == bimval_full[4]) and qpos_full['alt'].item() == bimval_full[5]
        condition2 = (qpos_full['ref'].item() == bimval_full[5]) and qpos_full['alt'].item() == bimval_full[4]
        if not (condition1 or condition2):
            # print(f"Mismatch at rsid {rsid}: {bimval} != {qpos}. \n Bimval: {bimval_full} \n Qpos: {qpos_full}", sep = ' ')
            mismatch.append((rsid, 'variant'))
# Out:
# 0it [00:00, ?it/s]
# 6930949it [02:36, 44254.47it/s]

# %%
len(mismatch)
# Out:
# 423394

# %%
#see how many are position
position = 0
variant = 0
for rsid, type in mismatch:
    if type == 'position':
        position += 1
    elif type == 'variant':
        variant += 1
print(position, variant) #so only an additional 20 are not perfectly alligned, yeah whatever let's just exclude these!
# Out:
# 1242 820

# %%
#now exclude them, make this subset array
# bad = [ rs for rs, *_ in mismatch_size ] + [ rs for rs, *_ in mismatch_values ]
bad = [ rs[0] for rs in mismatch ]
print(len(bad))
subset = unique.filter(~pl.col("rsid").is_in(bad))
subset
# Out:
# 423394
# shape: (6_508_373, 19)
# ┌────────────┬────────────┬───────────┬─────┬───┬────────────┬────────────┬────────────┬───────────┐
# │ molecular_ ┆ chromosome ┆ position  ┆ ref ┆ … ┆ molecular_ ┆ gene_id    ┆ median_tpm ┆ rsid      │
# │ trait_id   ┆ ---        ┆ ---       ┆ --- ┆   ┆ trait_obje ┆ ---        ┆ ---        ┆ ---       │
# │ ---        ┆ i64        ┆ i64       ┆ str ┆   ┆ ct_id      ┆ str        ┆ str        ┆ str       │
# │ str        ┆            ┆           ┆     ┆   ┆ ---        ┆            ┆            ┆           │
# │            ┆            ┆           ┆     ┆   ┆ str        ┆            ┆            ┆           │
# ╞════════════╪════════════╪═══════════╪═════╪═══╪════════════╪════════════╪════════════╪═══════════╡
# │ Interval_1 ┆ 1          ┆ 14464     ┆ A   ┆ … ┆ Interval_1 ┆ Interval_1 ┆ NA         ┆ rs5461694 │
# │            ┆            ┆           ┆     ┆   ┆            ┆            ┆            ┆ 44        │
# ...

# %% [markdown]
# this can be our subset, this includes only unique values and ones that match, can subset the full array with these to get duplicates, but these are values that are
# 1. SNP only (no indels)
# 2. no inconsistencies in the variant that appears
# 3. rsid is in bim files
# 4. matches exact position and variant as bim file

# %%
#final thing is to save this subset
subset.write_csv('/data1/lesliec/sarthak/data/joint_playground/caQTL/QTD100018.subset.tsv', separator='\t')

# %%
rsids = subset['rsid'].to_numpy()
rsids = {rsid: 0 for i, rsid in enumerate(rsids)}
rsids
# Out:
# {'rs546169444': 0,
#  'rs199856693': 0,
#  'rs199745162': 0,
#  'rs141149254': 0,
#  'rs114420996': 0,
#  'rs62637817': 0,
#  'rs80011619': 0,
#  'rs62639104': 0,
#  'rs556128788': 0,
#  'rs550285297': 0,
#  'rs147538909': 0,
#  'rs147502335': 0,
#  'rs375595668': 0,
#  'rs111659307': 0,
#  'rs367639380': 0,
#  'rs369556846': 0,
#  'rs28863004': 0,
#  'rs60396226': 0,
#  'rs144425991': 0,
#  'rs373360530': 0,
#  'rs373437560': 0,
#  'rs113952007': 0,
#  'rs185127847': 0,
#  'rs201942322': 0,
#  'rs371628865': 0,
#  'rs61769339': 0,
#  'rs539032812': 0,
#  'rs530588710': 0,
#  'rs146067153': 0,
#  'rs150820983': 0,
#  'rs190214723': 0,
#  'rs12238997': 0,
#  'rs61769351': 0,
#  'rs189800799': 0,
#  'rs142559957': 0,
#  'rs72631875': 0,
#  'rs113462541': 0,
#  'rs371890604': 0,
#  'rs200531508': 0,
#  'rs373285923': 0,
#  'rs12071806': 0,
#  'rs114983708': 0,
#  'rs12028261': 0,
#  'rs12184267': 0,
#  'rs12184277': 0,
#  'rs187772768': 0,
#  'rs116801199': 0,
#  'rs12565286': 0,
# ...

# %%
#now the thing is to loop through the the csv file and find how many times each rsid in this subset appears, can use a dictionary
tsv_file = '/data1/lesliec/sarthak/data/joint_playground/caQTL/QTD100018.all.tsv'
with open(tsv_file, 'r') as file:
    next(file)  # Skip the header line
    for line in tqdm(file, total=344_879_633):
        line = line.strip()
        line = line.split('\t')
        # print(line)

        rsid = line[-1]

        if rsid not in rsids:
            continue
        
        rsids[rsid] += 1
# Out:
# 100%|██████████| 344879633/344879633 [07:05<00:00, 810011.68it/s]

# %%
#total number of elements
total = 0
for rsid in rsids:
    total += rsids[rsid]
print(total)
# Out:
# 234077507

# %%
#now we can view the distribution of how many of each RSID there are, remember same position and variant
import matplotlib.pyplot as plt
import numpy as np

# Create a histogram of the counts
plt.figure(figsize=(8, 5))
plt.hist(list(rsids.values()), bins=100)
plt.xlabel('Count of rsids')
plt.ylabel('Frequency')
plt.title('Distribution of rsid counts')
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
#verify this with polars, make sure it's identical!
unique_rsids = subset['rsid'].unique().to_numpy()
unique_rsids = np.array(unique_rsids, dtype=str)
len(unique_rsids)
# Out:
# 6508373

# %%
ldf = pl.scan_csv(
    tsv_file,
    separator="\t",
    has_header=True,
    infer_schema_length=50_000,   # peek this many rows to infer dtypes
)

counts_lf = (
    ldf
    .filter(pl.col("rsid").is_in(unique_rsids))
    .group_by("rsid")
    .agg(pl.count().alias("count"))
)

unique_lf = pl.DataFrame({"rsid": unique_rsids}).lazy()

result = (
    unique_lf
    .join(counts_lf, on="rsid", how="left")
    .fill_null(0)         # missing counts → 0
)
result = result.collect()

result
# Out:
# shape: (6_508_373, 2)
# ┌────────────┬───────┐
# │ rsid       ┆ count │
# │ ---        ┆ ---   │
# │ str        ┆ u32   │
# ╞════════════╪═══════╡
# │ rs9614394  ┆ 21    │
# │ rs7646375  ┆ 73    │
# │ rs969503   ┆ 41    │
# │ rs16912423 ┆ 41    │
# │ …          ┆ …     │
# │ rs78745594 ┆ 38    │
# │ rs1333643  ┆ 13    │
# │ rs62025901 ┆ 32    │
# │ rs11655935 ┆ 4     │
# └────────────┴───────┘

# %%
rsids
# Out:
# {'rs546169444': 6,
#  'rs199856693': 6,
#  'rs199745162': 6,
#  'rs141149254': 6,
#  'rs114420996': 6,
#  'rs62637817': 6,
#  'rs80011619': 6,
#  'rs62639104': 6,
#  'rs556128788': 8,
#  'rs550285297': 8,
#  'rs147538909': 8,
#  'rs147502335': 8,
#  'rs375595668': 8,
#  'rs111659307': 6,
#  'rs367639380': 6,
#  'rs369556846': 6,
#  'rs28863004': 3,
#  'rs60396226': 3,
#  'rs144425991': 3,
#  'rs373360530': 3,
#  'rs373437560': 8,
#  'rs113952007': 12,
#  'rs185127847': 14,
#  'rs201942322': 15,
#  'rs371628865': 16,
#  'rs61769339': 16,
#  'rs539032812': 16,
#  'rs530588710': 16,
#  'rs146067153': 17,
#  'rs150820983': 17,
#  'rs190214723': 18,
#  'rs12238997': 18,
#  'rs61769351': 18,
#  'rs189800799': 19,
#  'rs142559957': 20,
#  'rs72631875': 20,
#  'rs113462541': 20,
#  'rs371890604': 20,
#  'rs200531508': 20,
#  'rs373285923': 21,
#  'rs12071806': 21,
#  'rs114983708': 21,
#  'rs12028261': 21,
#  'rs12184267': 21,
#  'rs12184277': 21,
#  'rs187772768': 21,
#  'rs116801199': 21,
# ...

# %%
#now loop through and verify things match
for i,rsid in tqdm(enumerate(result['rsid']), total=len(result['rsid'])):
    if rsid not in rsids:
        print(f"Missing rsid {rsid}")
        continue
    if rsids[rsid] != result['count'][i]:
        print(f"Mismatch at rsid {rsid}: {rsids[rsid]} != {result['count'][i]}")
        continue
# Out:
# ...
# 100%|██████████| 6508373/6508373 [02:53<00:00, 37496.40it/s]

# %%
#perfect match! Now create the file with all the subset

#rsids can be grabbed from the subset file, super easy to get!! 


tsv_file = '/data1/lesliec/sarthak/data/joint_playground/caQTL/QTD100018.all.tsv'
out_file = '/data1/lesliec/sarthak/data/joint_playground/caQTL/QTD100018.all_subset.tsv'
# with open(tsv_file, 'r') as file:
#     next(file)  # Skip the header line
#     for line in tqdm(file, total=344_879_633):
#         line_alt = line.strip()
#         line_alt = line_alt.split('\t')
#         # print(line)

#         rsid = line_alt[-1]

#         if rsid not in rsids:
#             continue
        #write at end
        
with open(tsv_file, 'r') as infile, open(out_file, 'w') as outfile:
    # 1) grab & write the header
    header = infile.readline()
    outfile.write(header)

    # 2) stream through data lines
    for line in tqdm(infile, total=344_879_633):
        fields = line.strip().split('\t')
        rsid = fields[-1]
        if rsid in rsids:
            outfile.write(line)
# Out:
# 100%|██████████| 344879633/344879633 [18:06<00:00, 317542.11it/s]

# %% [markdown]
# # rest of the preprocessing
# see if chrombpnet uses the replicates of the variants and what it does for the rest of the preprocessing
